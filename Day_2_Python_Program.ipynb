# %% [markdown]
# <a href="https://colab.research.google.com/github/MuthuBIN/EnzyemClassPred/blob/main/Day_2_Python_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= input("Enter First name")
b= input ("Enter Last Name")
print("===================")
print("Arthimatic operation on strings")
print("==============")
Full_Name=a+b+" " #Sring concatenation
print("Full Name=", Full_Name)
repeat_name=Full_Name*2
print("repeat_name=",repeat_name)
print("==============")
# Out:
# Enter First namemuthu
# Enter Last Namekumar
# ...
# Arthimatic operation on strings
# ...
# Full Name= muthukumar
# repeat_name= muthukumar muthukumar
# ...

# %%
# Precedence Operators

# %%
a= 20
b=30
c=40
print("Value1=", a+b*c)
print("Value1=", (a+b)*c)
print("Value1=", c/a+(b*2))
# Out:
# Value1= 1220
# Value1= 2000
# Value1= 62.0

# %%
num1=10
num2=0
num3=10
srt1="Good"
str2="Afternoon"

# %%
print("Status=",num1==num2)
print("Status=",num1==num3)
print("Status=",num1!=num2)
print("Status=",num1<num2)
print("Status=",num1>=num2)
print("Status=",num1<=num2)
# Out:
# Status= False
# Status= True
# Status= True
# Status= False
# Status= True
# Status= False

# %% [markdown]
# Logical Operators

# %%
num1=10
num2=0
num3=10
print("Status=", num1==num2 and num1==num3)
print("Status=", num1==num2 or num1==num3)
print("Status=", not (num1>=num3))
# Out:
# Status= False
# Status= True
# Status= False

# %% [markdown]
# Assignment OPerators

# %%
num1=10
print("num1=",num1)
num2=num1
print("num1=",num2)
num2=20
print("num2=",num2)
num1+num2
print("num1=", num1)

num2=num2**2
print("num2=", num2)
# Out:
# num1= 10
# num1= 10
# num2= 20
# num1= 10
# num2= 400

# %%
num1=10
print("num1=",num1)
num2=num1
print("num2=",num2)
num2+=num1
print("num2=",num2)
num2-=num1
print("num2=",num2)
num2*=num1
print("num2=",num2)
num2/=num1
print("num2=",num2)
num2%=num1
print("num2=",num2)
num2//=num1
print("num2=",num2)
num2**=num1
print("num2=",num2)
num2%=num1
print("num2=",num2)
# Out:
# num1= 10
# num2= 10
# num2= 20
# num2= 10
# num2= 100
# num2= 10.0
# num2= 0.0
# num2= 0.0
# num2= 0.0
# num2= 0.0

# %%
# Membership Operator

# %%
students=["Muthu", "Kumar"]
call_attendance=input("Call Student Name")
print("status1=", call_attendance in students)
print("status2=", call_attendance not in studnets)
# Out:
# Call Student NameKumar
# status1= True
# status2= False

# %% [markdown]
# Bitwise operator

# %%
a=10
b=5
print("Results=", a&b)
print("Results=", a|b)
print("Results=", ~a)
print("Results=", ~b)
print("Results=", a^b)
# Out:
# Results= 0
# Results= 15
# Results= -11
# Results= -6
# Results= 15
